# %% [markdown]
# # Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from IPython.core.debugger import set_trace
import json
from matplotlib import colors
from ast import literal_eval

# %% [markdown]
# # Load data

# %%
# psynet 11
fname = "manu-test-ising1"
fname = "singing-musicians-June-2026"
fname = "singing-musicians-July-2026"

PATH = f"data/{fname}/"
nodes = pd.read_csv(PATH + "CustomNode.csv", low_memory=False)
# networks = pd.read_csv(PATH + "CustomNetwork.csv", low_memory=False) # old psynet
trials = pd.read_csv(PATH + "CustomTrial.csv", low_memory=False)

# %%
print(nodes)
# Out:
#      vars    id        creation_time  failed failed_reason time_of_death  \
# 0      {}    17  2026-06-17 07:49:34   False           NaN           NaN
# 1      {}    18  2026-06-17 07:49:34   False           NaN           NaN
# 2      {}    19  2026-06-17 07:49:34   False           NaN           NaN
# 3      {}    20  2026-06-17 07:49:34   False           NaN           NaN
# 4      {}    21  2026-06-17 07:49:34   False           NaN           NaN
# ...   ...   ...                  ...     ...           ...           ...
# 3487   {}  3504  2026-07-26 18:32:43   False           NaN           NaN
# 3488   {}  3505  2026-07-26 18:32:57   False           NaN           NaN
# 3489   {}  3506  2026-07-26 18:33:23   False           NaN           NaN
# 3490   {}  3507  2026-07-26 18:33:42   False           NaN           NaN
# 3491   {}  3508  2026-07-26 18:33:56   False           NaN           NaN
#
#              type  network_id  participant_id   trial_maker_id  ... parent_id  \
# 0     TrialSource          17               1  imitation_chain  ...       NaN
# 1     TrialSource          18               1  imitation_chain  ...       NaN
# 2     TrialSource          19               1  imitation_chain  ...       NaN
# 3     TrialSource          20               1  imitation_chain  ...       NaN
# 4     TrialSource          21               1  imitation_chain  ...       NaN
# ...           ...         ...             ...              ...  ...       ...
# 3487   CustomNode         387             104  imitation_chain  ...    3500.0
# 3488   CustomNode         388             104  imitation_chain  ...    3502.0
# 3489   CustomNode         388             104  imitation_chain  ...    3505.0
# 3490   CustomNode         387             104  imitation_chain  ...    3504.0
# 3491   CustomNode         390             104  imitation_chain  ...    3503.0
#
#                                                    seed  \
# 0     {"register": "high", "reference_pitch": 61.513...
# 1     {"register": "high", "reference_pitch": 62.533...
# 2     {"register": "high", "reference_pitch": 61.719...
# 3     {"register": "high", "reference_pitch": 61.820...
# 4     {"register": "high", "reference_pitch": 61.488...
# ...                                                 ...
# 3487  {"reference_pitch": 59.83554718713076, "regist...
# 3488  {"reference_pitch": 60.856601707676425, "regis...
# 3489  {"reference_pitch": 61.44546019005024, "regist...
# 3490  {"reference_pitch": 59.61770022391349, "regist...
# 3491  {"reference_pitch": 59.29918452918062, "regist...
#
#                                              definition  context  \
# 0     {"register": "high", "reference_pitch": 61.513...      NaN
# 1     {"register": "high", "reference_pitch": 62.533...      NaN
# 2     {"register": "high", "reference_pitch": 61.719...      NaN
# 3     {"register": "high", "reference_pitch": 61.820...      NaN
# 4     {"register": "high", "reference_pitch": 61.488...      NaN
# ...                                                 ...      ...
# 3487  {"reference_pitch": 59.83554718713076, "regist...      NaN
# 3488  {"reference_pitch": 60.856601707676425, "regis...      NaN
# 3489  {"reference_pitch": 61.44546019005024, "regist...      NaN
# 3490  {"reference_pitch": 59.61770022391349, "regist...      NaN
# 3491  {"reference_pitch": 59.29918452918062, "regist...      NaN
#
#       participant_group    block  propagate_failure  n_viable_trials  \
# 0               default  default              False                1
# 1               default  default              False                1
# 2               default  default              False                1
# 3               default  default              False                1
# 4               default  default              False                1
# ...                 ...      ...                ...              ...
# 3487            default  default              False                1
# 3488            default  default              False                1
# 3489            default  default              False                0
# 3490            default  default              False                0
# 3491            default  default              False                0
#
#            class  object_type
# 0     CustomNode         Node
# 1     CustomNode         Node
# 2     CustomNode         Node
# 3     CustomNode         Node
# 4     CustomNode         Node
# ...          ...          ...
# 3487  CustomNode         Node
# 3488  CustomNode         Node
# 3489  CustomNode         Node
# 3490  CustomNode         Node
# 3491  CustomNode         Node
#
# [3492 rows x 33 columns]

# %%
# filter nodes
node_data = nodes
node_data = node_data[node_data["failed"] == False]
node_data = node_data[["id", "network_id", "degree", "trial_maker_id", "definition", "seed"]]
node_data = node_data.sort_values(["network_id", "degree"])
node_data["definition"].iloc[1]

print(node_data['definition'])
# Out:
# 0       {"register": "high", "reference_pitch": 61.513...
# 8       {"reference_pitch": 59.442037702692495, "regis...
# 11      {"reference_pitch": 61.5932768305512, "registe...
# 18      {"reference_pitch": 63.03794404910124, "regist...
# 22      {"reference_pitch": 59.76154684762448, "regist...
#                               ...
# 3478    {"reference_pitch": 61.08426073986259, "regist...
# 3481    {"reference_pitch": 62.49672216453698, "regist...
# 3484    {"reference_pitch": 59.814687916848555, "regis...
# 3486    {"reference_pitch": 63.298596816011916, "regis...
# 3491    {"reference_pitch": 59.29918452918062, "regist...
# Name: definition, Length: 3319, dtype: object

# %% [markdown]
# # Preprocess data

# %%
# filter nodes
node_data = nodes
node_data = node_data[node_data["failed"] == False]
node_data = node_data[["id", "network_id", "degree", "trial_maker_id", "definition", "seed"]]
node_data = node_data.sort_values(["network_id", "degree"])

# process node definition
mel_id = []
# register = []
trial_type = []
target_pitches = []
target_intervals = []
reference_pitch = []
target_note_durations = []

for i in range(len(node_data)):
    print()
    # definition = node_data["definition"].to_numpy()[i]
    # definition = literal_eval(definition)
    # definition = [d["content"] for d in definition if d["is_center"]][0]

    definition_str = node_data["definition"].iloc[i]  # Access the string directly
    print(definition_str)
    definition = json.loads(definition_str)  # Parse JSON string into dictionary
    # definition = [d["content"] for d in definition if d["is_center"]][0]
    
    # mel_id.append(definition["mel_id"])
    # register.append(definition["register"])
    trial_type.append(definition["trial_type"])
    target_pitches.append(definition["target_pitches"])
    reference_pitch.append(definition["reference_pitch"])
    target_intervals.append(definition["target_intervals"])

# node_data["mel_id"] = mel_id
# node_data["register"] = register
node_data["trial_type"] = trial_type
node_data["target_pitches"] = target_pitches
node_data["reference_pitch"] = reference_pitch
node_data["target_intervals"] = target_intervals
# Out:
# {"register": "high", "reference_pitch": 61.51365945675623, "max_interval2reference": 10, "max_interval_size": 5.5, "target_pitches": [62.26776695793315, 59.31690312168399, 67.74881709916347], "target_intervals": [-2.9508638362491553, 8.431913977479482], "target_intervals2reference": [0.754107501176918, -2.196756335072237, 6.235157642407245], "num_target_pitches": 3, "trial_type": "source_trial", "reference_mode": "pitch_mode"}
#
# {"reference_pitch":
"num_target_pitches": 3, "trial_type": "node_trial"}
#
# {"reference_pitch": 59.29918452918062, "register": "low", "target_pitches": [62.254522706609414, 69.80086962563689, 67.15742030990685], "target_intervals": [7.546346919027485, -2.6434493157300523], "target_intervals2reference": [2.955338177428793, 10.501685096456278, 7.8582357807262255], "num_target_pitches": 3, "trial_type": "node_trial"}

# %%
node_data
# Out:
#         id  network_id  degree   trial_maker_id  \
# 0       17          17       0  imitation_chain
# 8       25          17       1  imitation_chain
# 11      28          17       2  imitation_chain
# 18      35          17       3  imitation_chain
# 22      39          17       4  imitation_chain
# ...    ...         ...     ...              ...
# 3478  3495         390       6  imitation_chain
# 3481  3498         390       7  imitation_chain
# 3484  3501         390       8  imitation_chain
# 3486  3503         390       9  imitation_chain
# 3491  3508         390      10  imitation_chain
#
#                                              definition  \
# 0     {"register": "high", "reference_pitch": 61.513...
# 8     {"reference_pitch": 59.442037702692495, "regis...
# 11    {"reference_pitch": 61.5932768305512, "registe...
# 18    {"reference_pitch": 63.03794404910124, "regist...
# 22    {"reference_pitch": 59.76154684762448, "regist...
# ...                                                 ...
# 3478  {"reference_pitch": 61.08426073986259, "regist...
# 3481  {"reference_pitch": 62.49672216453698, "regist...
# 3484  {"reference_pitch": 59.814687916848555, "regis...
# 3486  {"reference_pitch": 63.298596816011916, "regis...
# 3491  {"reference_pitch": 59.29918452918062, "regist...
#
#                                                    seed    trial_type  \
# 0     {"register": "high", "reference_pitch": 61.513...  source_trial
# 8     {"reference_pitch": 59.442037702692495, "regis...    node_trial
# 11    {"reference_pitch": 61.5932768305512, "registe...    node_trial
# 18    {"reference_pitch": 63.03794404910124, "regist...    node_trial
# 22    {"reference_pitch": 59.76154684762448, "regist...    node_trial
# ...                                                 ...           ...
# 3478  {"reference_pitch": 61.08426073986259, "regist...    node_trial
# 3481  {"reference_pitch": 62.49672216453698, "regist...    node_trial
# 3484  {"reference_pitch": 59.814687916848555, "regis...    node_trial
# 3486  {"reference_pitch": 63.298596816011916, "regis...    node_trial
# 3491  {"reference_pitch": 59.29918452918062, "regist...    node_trial
#
#                                          target_pitches  reference_pitch  \
# 0     [62.26776695793315, 59.31690312168399, 67.7488...        61.513659
# 8     [58.675315655120436, 56.67578458605753, 65.713...        59.442038
# 11    [59.80697032178534, 58.13777038659859, 67.2834...        61.593277
# 18    [58.94231446422989, 57.36454643446263, 68.7316...        63.037944
# 22    [53.81551845974534, 52.68381431046352, 64.9807...        59.761547
# ...                                                 ...              ...
# 3478  [64.33417418903008, 71.55188203764706, 69.5993...        61.084261
# 3481  [65.73622347951517, 72.91431263840802, 70.8485...        62.496722
# 3484  [62.76431241023546, 70.19097474225259, 67.8975...        59.814688
# 3486  [65.90751979742541, 73.50753893298048, 71.6393...        63.298597
# 3491  [62.254522706609414, 69.80086962563689, 67.157...        59.299185
#
#                                target_intervals
# 0      [-2.9508638362491553, 8.431913977479482]
# 8       [-1.999531069062904, 9.037313163158935]
# 11     [-1.6691999351867537, 9.145642855653705]
# 18     [-1.577768029767256, 11.367107178988434]
# 22    [-1.1317041492818234, 12.296938336247955]
# ...                                         ...
# 3478   [7.217707848616982, -1.9524964559052762]
# 3481  [7.1780891588928455, -2.0657154746104283]
# 3484  [7.4266623320171234, -2.2934709373805333]
# 3486   [7.600019135555073, -1.8681810795361287]
# 3491   [7.546346919027485, -2.6434493157300523]
#
# [3319 rows x 10 columns]

# %% [markdown]
# # Export node data to csv

# %%
node_data.to_csv(f"{fname}_node_data.csv")

# %% [markdown]
# # Trial level data

# %%
# filter trials
trial_data = trials
trial_data = trial_data[trial_data["failed"] == False]

degrees = []

for i in range(len(trial_data)):
    current_node_id = trial_data.iloc[i]["origin_id"]
    current_nodes = node_data[node_data["id"] == current_node_id]
    current_degree = current_nodes["degree"].to_numpy()[0]
    # answer = d['listen_and_rate_trial_seed']['valence']
    # current_vertex_id = current_nodes["vertex_id"].to_numpy()[0]
    # current_dependent_vertex_ids = current_nodes["dependent_vertex_ids"].to_numpy()[0]
    degrees.append(current_degree)
    # vertex_ids.append(current_vertex_id)
    # dependent_vertex_ids.append(current_dependent_vertex_ids)

trial_data["degree"] = degrees

trial_data = trial_data[["id", "network_id", "degree", "trial_maker_id", "origin_id", "participant_id", "analysis"]]
trial_data = trial_data.sort_values(["network_id", "degree"])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 10
#       8 current_node_id = trial_data.iloc[i]["origin_id"]
#       9 current_nodes = node_data[node_data["id"] == current_node_id]
# ---> 10 current_degree = current_nodes["degree"].to_numpy()[0]
#      11 # answer = d['listen_and_rate_trial_seed']['valence']
#      12 # current_vertex_id = current_nodes["vertex_id"].to_numpy()[0]
#      13 # current_dependent_vertex_ids = current_nodes["dependent_vertex_ids"].to_numpy()[0]
#      14 degrees.append(current_degree)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
trial_data
# Out:
#         id  network_id  degree   trial_maker_id  origin_id  participant_id  \
# 4       17          17       0  imitation_chain         17               3
# 6       19          17       1  imitation_chain         26               3
# 12      25          17       2  imitation_chain         28               3
# 18      31          17       3  imitation_chain         34               3
# 20      33          17       4  imitation_chain         40               3
# ...    ...         ...     ...              ...        ...             ...
# 1274  1560         141       5  imitation_chain       1097              32
# 1279  1565         141       6  imitation_chain       1103              32
# 1287  1573         141       7  imitation_chain       1108              32
# 1290  1576         141       8  imitation_chain       1114              32
# 1292  1578         141       9  imitation_chain       1117              32
#
#                                                analysis
# 4     {"failed": false, "reason": "All good", "regis...
# 6     {"failed": false, "reason": "All good", "regis...
# 12    {"failed": false, "reason": "All good", "regis...
# 18    {"failed": false, "reason": "All good", "regis...
# 20    {"failed": false, "reason": "All good", "regis...
# ...                                                 ...
# 1274  {"failed": false, "reason": "All good", "regis...
# 1279  {"failed": false, "reason": "All good", "regis...
# 1287  {"failed": false, "reason": "All good", "regis...
# 1290  {"failed": false, "reason": "All good", "regis...
# 1292  {"failed": false, "reason": "All good", "regis...
#
# [972 rows x 7 columns]

# %% [markdown]
# # Export trial data to csv

# %%
trial_data.to_csv(f"{fname}_trial_data.csv")

# %% [markdown]
# # Experiment Cost and Demographics

# %%
participants = pd.read_csv(PATH + "participant.csv", low_memory=False)

# %%
valid_participants = participants[participants["complete"] == True]
valid_participants = valid_participants[valid_participants["failed"] == False]
experiment_summary = {
    "N_participants": valid_participants.shape[0],
    "cost": participants["base_pay"].sum() + participants["bonus"].sum()
}

experiment_summary
# Out:
# {'N_participants': 24, 'cost': 0.0}
